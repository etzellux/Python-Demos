# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2
from collections import Counter

# %%
### BACKGROUND'I SİLME

# %%
img = cv2.imread("hmgoepprod.jpg")
img = cv2.resize(img,(400,500))

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img_gray,cmap="gray")

# %%
img_gray
# Out:
# array([[244, 244, 244, ..., 243, 243, 243],
#        [234, 234, 234, ..., 231, 231, 231],
#        [233, 233, 233, ..., 231, 231, 230],
#        ...,
#        [230, 230, 230, ..., 230, 230, 230],
#        [230, 230, 230, ..., 230, 230, 230],
#        [230, 230, 230, ..., 230, 230, 231]], dtype=uint8)

# %%
img_gray[img_gray>=220] = 0

# %%
plt.imshow(img_gray,cmap="gray")

# %%
ret,thresh1 = cv2.threshold(img_gray,127,255,cv2.THRESH_BINARY)

# %%
thresh1.shape
# Out:
# (500, 400)

# %%
plt.imshow(thresh1,cmap="gray")

# %%
kernel1 = np.ones((7,7),dtype=np.float32)
kernel2 = np.ones((2,2),dtype=np.float32)

# %%
thresh1 = cv2.dilate(thresh1,kernel1)

# %%
plt.imshow(thresh1,cmap="gray")

# %%
thresh1 = cv2.erode(thresh1,kernel2)

# %%
plt.imshow(thresh1,cmap="gray")

# %%
mask1 = thresh1

# %%
mask1 = cv2.bitwise_or(img,img,mask=mask1)

# %%
plt.imshow(mask1)

# %%
mask1.shape
# Out:
# (500, 400, 3)

# %%
for i in mask1:
    for j in i:
        if j[0] == 0 & j[1] == 0 & j[2] == 0 :
            j[0] = -3
            j[1] = -3
            j[2] = -3

# %%
### PREPROCESSING

# %%
flatten_img = mask1.reshape((mask1.shape[0]*mask1.shape[1],3))

# %%
### BUILDING MODEL

# %%
number_of_colors = 3  ### CLUSTER SAYISI

# %%
model = KMeans(n_clusters = number_of_colors)
labels = model.fit_predict(flatten_img)

# %%
counts = Counter(labels)

# %%
colors = model.cluster_centers_

# %%
def RGB2HEX(color):
    return "#{:02x}{:02x}{:02x}".format(int(color[0]), int(color[1]), int(color[2]))

# %%
colors
# Out:
# array([[252.34576032, 252.35680453, 252.37090583],
#        [176.04990466, 190.96450332, 214.65542701],
#        [ 60.84696824,  65.88450433,  80.81135707]])

# %%
counts
# Out:
# Counter({0: 129208, 1: 69753, 2: 1039})

# %%
ordered_colors = [colors[i] for i in counts.keys()]

# %%
ordered_colors
# Out:
# [array([0.27783612, 0.29414255, 0.35798429]),
#  array([229.53632532, 229.45115299, 229.23146541]),
#  array([175.17657274, 190.24674742, 214.22710893])]

# %%
hex_colors = [RGB2HEX(ordered_colors[i]) for i in counts.keys()]

# %%
plt.figure(figsize = (8, 6))
plt.pie(counts.values(), labels = hex_colors, colors = hex_colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f1cb54aef0>,
# ...
#  [Text(-0.386154,1.02999,'#e5e5e5'),
#   Text(-0.730858,-0.822099,'#afbed6'),
#   Text(0.51321,-0.972941,'#000000')])

# %%
hex_colors
# Out:
# ['#e5e5e5', '#afbed6', '#000000']

# %%
ordered_counts = np.zeros((3))
a = 0

# %%
for i in counts.values():
    ordered_counts[a] = i
    a += 1

# %%
ordered_counts = np.sort(ordered_counts,axis=-1)

# %%
ordered_counts
# Out:
# array([  8066.,  69099., 122835.])

# %%
plt.figure(figsize = (8, 6))
plt.pie(ordered_counts, labels = hex_colors, colors = hex_colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f1cb3bb780>,
# ...
#  [Text(1.09118,0.138998,'#e5e5e5'),
#   Text(0.252907,1.07053,'#afbed6'),
#   Text(-0.386154,-1.02999,'#000000')])
